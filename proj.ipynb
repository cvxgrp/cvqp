# %%
from analysis_utils import *
from benchmark_proj import *

import warnings
warnings.filterwarnings('ignore')

# %%
# Load all results
results = load_all_results()

# Create the plots
plot_proj_benchmarks(results, save_figures=True)

# Display the tables
display_benchmark_tables(results)
# Out:
# Benchmark Results (τ = 0.1)
# <style type="text/css">
# #T_e63d7 th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_e63d7 td {
#   border: 1px solid #666;
# }
# ...
