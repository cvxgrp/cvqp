# %%
from plotting_utils import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Projection benchmarks

# %%
proj_results = load_proj_results()
plot_proj_benchmarks(proj_results, save_figures=False)
display_benchmark_tables(proj_results, proj_config)
# Out:
# Benchmark Results (τ = 0.1)
# <style type="text/css">
# #T_5e1de th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_5e1de td {
#   border: 1px solid #666;
# }
# ...

# %% [markdown]
# ## CVQP benchmarks

# %%
portfolio_results = load_cvqp_results('portfolio')
plot_cvqp_benchmarks(portfolio_results, save_figures=False)
display_benchmark_tables(portfolio_results, cvqp_config)
# Out:
# Benchmark Results (n_vars = 100)
# <style type="text/css">
# #T_a19c7 th {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# #T_a19c7 td {
#   border: 1px solid #666;
# }
# #T_a19c7_row0_col0, #T_a19c7_row0_col1, #T_a19c7_row0_col2, #T_a19c7_row0_col3, #T_a19c7_row0_col4, #T_a19c7_row0_col5, #T_a19c7_row0_col6, #T_a19c7_row1_col0, #T_a19c7_row1_col1, #T_a19c7_row1_col2, #T_a19c7_row1_col3, #T_a19c7_row1_col4, #T_a19c7_row1_col5, #T_a19c7_row1_col6, #T_a19c7_row2_col0, #T_a19c7_row2_col1, #T_a19c7_row2_col2, #T_a19c7_row2_col3, #T_a19c7_row2_col4, #T_a19c7_row2_col5, #T_a19c7_row2_col6 {
#   text-align: center;
#   padding: 8px;
#   border: 1px solid #666;
# }
# </style>
# <table id="T_a19c7">
#   <thead>
#     <tr>
#       <th id="T_a19c7_level0_col0" class="col_heading level0 col0" >Scenarios</th>
#       <th id="T_a19c7_level0_col1" class="col_heading level0 col1" colspan="3">Solve Times (seconds)</th>
# ...
